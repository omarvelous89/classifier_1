# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-b0175374-8e9c-4e28-93e1-349812ecbbd2" name="files[]" multiple disabled />
#      <output id="result-b0175374-8e9c-4e28-93e1-349812ecbbd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving amazon_cells_labelled.txt to amazon_cells_labelled (4).txt

# %%
import io
amz = pd.read_csv(io.BytesIO(data['amazon_cells_labelled.txt']), delimiter= '\t', header=None)

# %%
amz.columns = ['message', 'positive']
amz['message'] = amz['message'].str.replace('[^\w\s]','')
amz.head()
# Out:
#                                              message  positive
# 0  So there is no way for me to plug it in here i...         0
# 1                          Good case Excellent value         1
# 2                              Great for the jawbone         1
# 3  Tied to charger for conversations lasting more...         0
# 4                                   The mic is great         1

# %%
#Version 5 added new words: loved, highly recommend, ideal, best

keywords = ['great' , 'awesome' , 'love' , 'loved' , 'best', 'excellent' , 'good' , 'nice' , 'impressed' , 'very good' , 'very nice' , 'very well' , 'highly recommend' , 'ideal' , 'fine']

for key in keywords:

    pat = "(?i)(?:$|^| )({})(?:$|^| )".format(key)
    amz[str(key)] = amz.message.str.contains(pat = pat, regex=True)
# This is a really efficient loop. I don't know why it stood out 

amz['positive'].value_counts()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# 1    500
# 0    500
# Name: positive, dtype: int64

# %%
amz.head(60)


# question here. number 1 has false for good but true for excellent. number 2 has false for great as does number 4
# number 10 says great but also reads false.
# Out:
#                                               message  positive  great  \
# 0   So there is no way for me to plug it in here i...         0  False
# 1                           Good case Excellent value         1  False
# 2                               Great for the jawbone         1   True
# 3   Tied to charger for conversations lasting more...         0  False
# 4                                    The mic is great         1   True
# 5   I have to jiggle the plug to get it to line up...         0  False
# 6   If you have several dozen or several hundred c...         0  False
# 7             If you are Razr owneryou must have this         1  False
# 8                   Needless to say I wasted my money         0  False
# 9                      What a waste of money and time         0  False
# 10                     And the sound quality is great         1   True
# 11  He was very impressed when going from the orig...         1  False
# 12  If the two were seperated by a mere 5 ft I sta...         0  False
# 13                           Very good quality though         1  False
# 14  The design is very odd as the ear clip is not ...         0  False
# 15  Highly recommend for any one who has a blue to...         1  False
# 16                 I advise EVERYONE DO NOT BE FOOLED         0  False
# 17                                     So Far So Good         1  False
# 18                                        Works great         1   True
# 19  It clicks into place in a way that makes you w...         0  False
# 20  I went on Motorolas website and followed all d...         0  False
# 21  I bought this to use with my Kindle Fire and a...         1  False
# 22            The commercials are the most misleading         0  False
# 23  I have yet to run this new battery below two b...         1  False
# 24  I bought it for my mother and she had a proble...         0  False
# 25                 Great Pocket PC  phone combination         1   True
# 26  Ive owned this phone for 7 months now and can ...         1  False
# 27  I didnt think that the instructions provided w...         0  False
# 28  People couldnt hear me talk and I had to pull ...         0  False
# 29                                 Doesnt hold charge         0  False
# 30  This is a simple little phone to use but the b...         0  False
# 31  This product is ideal for people like me whose...         1  False
# 32    It is unusable in a moving car at freeway speed         0  False
# 33  I have two more years left in this contract an...         0  False
# 34  Car charger as well as AC charger are included...         1  False
# 35  You need at least 3 mins to get to your phone ...         0  False
# 36                           It has kept up very well         1  False
# 37                         Poor Talk Time Performance         0  False
# 38      The case is great and works fine with the 680         1   True
# 39                                  worthless product         0  False
# 40  It has a great camera thats 2MP and the pics a...         1   True
# 57    False  False      False  False  False  False      False      False
# 58    False  False      False  False  False  False      False      False
# 59    False  False      False  False  False  False      False      False
#
#     very nice  highly recommend  loved   best  ideal  very well   fine
# 0       False             False  False  False  False      False  False
# 1       False             False  False  False  False      False  False
# 2       False             False  False  False  False      False  False
# 3       False             False  False  False  False      False  False
# 4       False             False  False  False  False      False  False
# 5       False             False  False  False  False      False  False
# 6       False             False  False  False  False      False  False
# 7       False             False  False  False  False      False  False
# 8       False             False  False  False  False      False  False
# 9       False             False  False  False  False      False  False
# 10      False             False  False  False  False      False  False
# 11      False             False  False  False  False      False  False
# 12      False             False  False  False  False      False  False
# 13      False             False  False  False  False      False  False
# 14      False             False  False  False  False      False  False
# 15      False              True  False  False  False      False  False
# 16      False             False  False  False  False      False  False
# 17      False             False  False  False  False      False  False
# 18      False             False  False  False  False      False  False
# 19      False             False  False  False  False      False  False
# 20      False             False  False  False  False      False  False
# 21      False             False   True  False  False      False  False
# 22      False             False  False  False  False      False  False
# 23      False             False  False  False  False      False  False
# 24      False             False  False  False  False      False  False
# 25      False             False  False  False  False      False  False
# 26      False             False  False   True  False      False  False
# 27      False             False  False  False  False      False  False
# 28      False             False  False  False  False      False  False
# 29      False             False  False  False  False      False  False
# 30      False             False  False  False  False      False  False
# 31      False             False  False  False   True      False  False
# 32      False             False  False  False  False      False  False
# 33      False             False  False  False  False      False  False
# 34      False             False  False  False  False      False  False
# 35      False             False  False  False  False      False  False
# 36      False             False  False  False  False       True  False
# 37      False             False  False  False  False      False  False
# 38      False             False  False  False  False      False   True
# 39      False             False  False  False  False      False  False
# 40      False             False  False  False  False      False  False
# 41      False             False  False  False  False      False  False
# 42      False             False  False  False  False      False  False
# 43      False             False  False  False  False      False  False
# 44      False             False  False  False  False      False  False
# 45      False             False  False  False  False      False  False
# 46      False             False  False  False  False      False  False
# 47      False             False  False  False  False      False  False
# 48      False             False  False  False  False      False  False
# 49      False             False  False  False  False      False  False
# 50      False             False  False  False  False      False  False
# 51      False             False  False  False  False      False  False
# 52      False             False  False  False  False      False  False
# 53      False             False  False  False  False      False  False
# 54      False             False  False  False  False      False  False
# 55      False             False  False  False  False      False   True
# 56      False             False  False  False  False      False  False
# 57      False             False  False  False  False      False  False
# 58      False             False  False  False  False      False  False
# 59      False             False  False  False  False      False  False

# %%
data = amz[keywords]
target = amz['positive']

# %%
print(amz['message'][23], "\n" ,amz['message'][36], "\n" , amz['message'][41], "\n" , amz['message'][45], "\n"  , amz['message'][55], "\n"   , amz['message'][53])
# Out:
# I have yet to run this new battery below two bars and thats three days without charging
#  It has kept up very well
#  I was not impressed by this product
#  It has all the features I want
#  Everything about it is fine and reasonable for the price ie
#  This phone is pretty sturdy and Ive never had any large problems with it

# %%
#Our data is binary / boolean, so we're importing the Bernoulli classifier.
from sklearn.naive_bayes import BernoulliNB

# Instantiate our model and store it in a new variable.
bnb = BernoulliNB()

# Fit our model to the data.
bnb.fit(data, target)

# Classify, storing the result in a new variable.
y_pred = bnb.predict(data)

# Display our results.
print("Number of mislabeled points out of a total {} points : {}".format(
    data.shape[0],
    (target != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 1000 points : 275

# %%
#-------------- Below here I am testing out things we worked on in the lesson-----------------------
from sklearn.metrics import confusion_matrix
confusion_matrix(target, y_pred)

#--- I can identify bad reviews well but i do not identify good reviews well
# This goes in line with the observation above about odd classifications from the loop.
# Out:
# array([[476,  24],
#        [251, 249]])

# %%
# Test your model with different holdout groups.

from sklearn.model_selection import train_test_split
# Use train_test_split to create the necessary training and test groups
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=20)
print('With 20% Holdout: ' + str(bnb.fit(X_train, y_train).score(X_test, y_test)))
print('Testing on Sample: ' + str(bnb.fit(data, target).score(data, target)))
# Out:
# With 20% Holdout: 0.605
# Testing on Sample: 0.647

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(bnb, data, target, cv=10)

# Here I am doing cross validation. which is the same process above but iterated n times
#consistent scores are good but my model is poor but still consistent. this is like
#t-tests again.
# Out:
# array([0.68, 0.69, 0.72, 0.67, 0.64, 0.64, 0.62, 0.58, 0.65, 0.58])

# %%
amz['predictions']= y_pred
amz['correct'] = amz['positive'] == amz['predictions']
amz.head(25)
# Out:
#                                               message  positive  great  \
# 0   So there is no way for me to plug it in here i...         0  False
# 1                         Good case, Excellent value.         1  False
# 2                              Great for the jawbone.         1   True
# 3   Tied to charger for conversations lasting more...         0  False
# 4                                   The mic is great.         1  False
# 5   I have to jiggle the plug to get it to line up...         0  False
# 6   If you have several dozen or several hundred c...         0  False
# 7         If you are Razr owner...you must have this!         1  False
# 8                 Needless to say, I wasted my money.         0  False
# 9                    What a waste of money and time!.         0  False
# 10                    And the sound quality is great.         1  False
# 11  He was very impressed when going from the orig...         1  False
# 12  If the two were seperated by a mere 5+ ft I st...         0  False
# 13                           Very good quality though         1  False
# 14  The design is very odd, as the ear "clip" is n...         0  False
# 15  Highly recommend for any one who has a blue to...         1  False
# 16                I advise EVERYONE DO NOT BE FOOLED!         0  False
# 17                                   So Far So Good!.         1  False
# 18                                      Works great!.         1  False
# 19  It clicks into place in a way that makes you w...         0  False
# 20  I went on Motorola's website and followed all ...         0  False
# 21  I bought this to use with my Kindle Fire and a...         1  False
# 22           The commercials are the most misleading.         0  False
# 23  I have yet to run this new battery below two b...         1  False
# 24  I bought it for my mother and she had a proble...         0  False
#
#     awesome   love  excellent   good  bonus   nice  predictions  correct
# 0     False  False      False  False  False  False            0     True
# 1     False  False       True   True  False  False            1     True
# 2     False  False      False  False  False  False            1     True
# 3     False  False      False  False  False  False            0     True
# 4     False  False      False  False  False  False            0    False
# 5     False  False      False  False  False  False            0     True
# 6     False  False      False  False  False  False            0     True
# 7     False  False      False  False  False  False            0    False
# 8     False  False      False  False  False  False            0     True
# 9     False  False      False  False  False  False            0     True
# 10    False  False      False  False  False  False            0    False
# 11    False  False      False  False  False  False            0    False
# 12    False  False      False  False  False  False            0     True
# 13    False  False      False   True  False  False            1     True
# 14    False  False      False  False  False  False            0     True
# 15    False  False      False  False  False  False            0    False
# 16    False  False      False  False  False  False            0     True
# 17    False  False      False  False  False  False            0    False
# 18    False  False      False  False  False  False            0    False
# 19    False  False      False  False  False  False            0     True
# 20    False  False      False  False  False  False            0     True
# 21    False  False      False  False  False  False            0    False
# 22    False  False      False  False  False  False            0     True
# 23    False  False      False  False  False  False            0    False
# 24    False  False      False  False  False  False            0     True
